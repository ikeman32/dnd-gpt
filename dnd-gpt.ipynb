# %%
import torch
import torch.nn as nn
from torch.nn import functional as F
from torch.optim.lr_scheduler import CosineAnnealingWarmRestarts
import mmap
import random
import pickle
import argparse

parser = argparse.ArgumentParser(description='This is a demonstration program')

# Here we add an argument to the parser, specifying the expected type, a help message, etc.
# parser.add_argument('-batch_size', type=str, required=True, help='Please provide a batch_size')

# args = parser.parse_args()

# Now we can use the argument value in our program.
# print(f'batch size: {args.batch_size}')
device = 'cuda' if torch.cuda.is_available() else 'cpu'

# batch_size = args.batch_size # to use the batch_size cmd arg -> python file_name.py -batch_size 32
batch_size = 256
block_size = 128
max_iters = 20000
learning_rate = 1e-4
eval_iters = 500
n_embd = 768
n_head = 8
n_layer = 12
dropout = 0.1

# for text generation
temperature = 0.8

print(device)
# Out:
# cuda

# %%
chars = ""
with open("vocab.txt", 'r', encoding='utf-8') as f:
        text = f.read()
        chars = sorted(list(set(text)))
        
vocab_size = len(chars)

# %%
string_to_int = { ch:i for i,ch in enumerate(chars) }
int_to_string = { i:ch for i,ch in enumerate(chars) }
encode = lambda s: [string_to_int[c] for c in s]
decode = lambda l: ''.join([int_to_string[i] for i in l])

# %%
# memory map for using small snippets of text from a single file of any size
def get_random_chunk(split):
    filename = "train_split.txt" if split == 'train' else "val_split.txt"
    with open(filename, 'rb') as f:
        with mmap.mmap(f.fileno(), 0, access=mmap.ACCESS_READ) as mm:
            # Determine the file size and a random position to start reading
            file_size = len(mm)
            start_pos = random.randint(0, (file_size) - block_size*batch_size)

            # Seek to the random position and read the block of text
            mm.seek(start_pos)
            block = mm.read(block_size*batch_size-1)

            # Decode the block to a string, ignoring any invalid byte sequences
            decoded_block = block.decode('utf-8', errors='ignore').replace('\r', '')
            
            # Train and test splits
            data = torch.tensor(encode(decoded_block), dtype=torch.long)
            
    return data


def get_batch(split):
    data = get_random_chunk(split)
    ix = torch.randint(len(data) - block_size, (batch_size,))
    x = torch.stack([data[i:i+block_size] for i in ix])
    y = torch.stack([data[i+1:i+block_size+1] for i in ix])
    x, y = x.to(device), y.to(device)
    return x, y

# %%
class Head(nn.Module):
    """ one head of self-attention """

    def __init__(self, head_size):
        super().__init__()
        self.key = nn.Linear(n_embd, head_size, bias=False)
        self.query = nn.Linear(n_embd, head_size, bias=False)
        self.value = nn.Linear(n_embd, head_size, bias=False)
        self.register_buffer('tril', torch.tril(torch.ones(block_size, block_size)))

        self.dropout = nn.Dropout(dropout)

    def forward(self, x):
        # input of size (batch, time-step, channels)
        # output of size (batch, time-step, head size)
        B,T,C = x.shape
        k = self.key(x)   # (B,T,hs)
        q = self.query(x) # (B,T,hs)
        # compute attention scores ("affinities")
        wei = q @ k.transpose(-2,-1) * k.shape[-1]**-0.5 # (B, T, hs) @ (B, hs, T) -> (B, T, T)
        wei = wei.masked_fill(self.tril[:T, :T] == 0, float('-inf')) # (B, T, T)
        wei = F.softmax(wei, dim=-1) # (B, T, T)
        wei = self.dropout(wei)
        # perform the weighted aggregation of the values
        v = self.value(x) # (B,T,hs)
        out = wei @ v # (B, T, T) @ (B, T, hs) -> (B, T, hs)
        return out

# [1, 0, 0]
# [1, 0.6, 0]
# [1, 0.6, 0.4]
class MultiHeadAttention(nn.Module):
    """ multiple heads of self-attention in parallel """

    def __init__(self, num_heads, head_size):
        super().__init__()
        self.heads = nn.ModuleList([Head(head_size) for _ in range(num_heads)])
        self.proj = nn.Linear(head_size * num_heads, n_embd)
        self.dropout = nn.Dropout(dropout)

    def forward(self, x):
        out = torch.cat([h(x) for h in self.heads], dim=-1) # (B, T, F) -> (B, T, [h1, h1, h1, h1, h2, h2, h2, h2, h3, h3, h3, h3])
        out = self.dropout(self.proj(out))
        return out
    

class FeedFoward(nn.Module):
    """ a simple linear layer followed by a non-linearity """

    def __init__(self, n_embd):
        super().__init__()
        self.net = nn.Sequential(
            nn.Linear(n_embd, 4 * n_embd),
            nn.ReLU(),
            nn.Linear(4 * n_embd, n_embd),
            nn.Dropout(dropout),
        )

    def forward(self, x):
        return self.net(x)
    
class Block(nn.Module):
    """ Transformer block: communication followed by computation """

    def __init__(self, n_embd, n_head):
        # n_embd: embedding dimension, n_head: the number of heads we'd like
        super().__init__()
        head_size = n_embd // n_head
        self.sa = MultiHeadAttention(n_head, head_size)
        self.ffwd = FeedFoward(n_embd)
        self.ln1 = nn.LayerNorm(n_embd)
        self.ln2 = nn.LayerNorm(n_embd)

    def forward(self, x):
        y = self.sa(x)
        x = self.ln1(x + y)
        y = self.ffwd(x)
        x = self.ln2(x + y)
        return x
    
class GPTLanguageModel(nn.Module):
    def __init__(self, vocab_size):
        super().__init__()
        self.token_embedding_table = nn.Embedding(vocab_size, n_embd)
        self.position_embedding_table = nn.Embedding(block_size, n_embd)
        self.blocks = nn.Sequential(*[Block(n_embd, n_head=n_head) for _ in range(n_layer)])
        self.ln_f = nn.LayerNorm(n_embd) # final layer norm
        self.lm_head = nn.Linear(n_embd, vocab_size)
        
        
        self.apply(self._init_weights)

    def _init_weights(self, module):
        if isinstance(module, nn.Linear):
            torch.nn.init.normal_(module.weight, mean=0.0, std=0.02)
            if module.bias is not None:
                torch.nn.init.zeros_(module.bias)
        elif isinstance(module, nn.Embedding):
            torch.nn.init.normal_(module.weight, mean=0.0, std=0.02)

    def forward(self, index, targets=None):
        B, T = index.shape
        
        
        # idx and targets are both (B,T) tensor of integers
        tok_emb = self.token_embedding_table(index) # (B,T,C)
        pos_emb = self.position_embedding_table(torch.arange(T, device=device)) # (T,C)
        x = tok_emb + pos_emb # (B,T,C)
        x = self.blocks(x) # (B,T,C)
        x = self.ln_f(x) # (B,T,C)
        logits = self.lm_head(x) # (B,T,vocab_size)
        
        if targets is None:
            loss = None
        else:
            B, T, C = logits.shape
            logits = logits.view(B*T, C)
            targets = targets.view(B*T)
            loss = F.cross_entropy(logits, targets)
        
        return logits, loss
    
    def generate(self, index, max_new_tokens, temperature=temperature):
        # index is (B, T) array of indices in the current context
        for _ in range(max_new_tokens):
            # crop idx to the last block_size tokens
            index_cond = index[:, -block_size:]
            
            # get the predictions
            logits, loss = self.forward(index_cond)
            
            # focus only on the last time step
            logits = logits[:, -1, :] # becomes (B, C)
            
            # Apply temperature scaling
            if temperature > 0:
                logits = logits / max(temperature, 1e-6)

            # Normalize logits to prevent overflow in softmax
            logits = logits - logits.max(dim = -1, keepdim = True)[0]
            
            # apply softmax to get probabilities
            probs = F.softmax(logits, dim=-1) # (B, C)   

            # Add small epsilon to prevent zero probabilities
            probs = probs + 1e-8  
            probs = probs / probs.sum(dim=-1, keepdim=True)  # Re-normalize

            # sample from the distribution
            index_next = torch.multinomial(probs, num_samples=1) # (B, 1)
            
            # append sampled index to the running sequence
            index = torch.cat((index, index_next), dim=1) # (B, T+1)
        return index

model = GPTLanguageModel(vocab_size)
print('loading model parameters...')
with open('model-01.pkl', 'rb') as f:
    model = pickle.load(f)
print('loaded successfully!')
m = model.to(device)
# Out:
# loading model parameters...
# loaded successfully!

# %%
@torch.no_grad()
def estimate_loss():
    out = {}
    model.eval()
    for split in ['train', 'val']:
        losses = torch.zeros(eval_iters)
        for k in range(eval_iters):
            X, Y = get_batch(split)
            logits, loss = model(X, Y)
            losses[k] = loss.item()
        out[split] = losses.mean()
    model.train()
    return out

# %%
# create a PyTorch optimizer
optimizer = torch.optim.AdamW(model.parameters(), lr=learning_rate)

scheduler = CosineAnnealingWarmRestarts(optimizer, T_0=5000, T_mult=1, eta_min=1e-8)

for iter in range(max_iters):
    print(iter)
    if iter % eval_iters == 0:
        losses = estimate_loss()
        print(f"step: {iter}, train loss: {losses['train']:.3f}, val loss: {losses['val']:.3f}")
        with open('loss.txt', 'a' ) as l:
            l.write(f"step: {iter}, train loss: {losses['train']:.3f}, val loss: {losses['val']:.3f}\n")

    # sample a batch of data
    xb, yb = get_batch('train')

    # evaluate the loss
    logits, loss = model.forward(xb, yb)
    optimizer.zero_grad(set_to_none=True)
    loss.backward()
    optimizer.step()
    # Step the scheduler at each iteration
    scheduler.step()

    # Print current learning rate
    print(f'Current learning rate: {scheduler.get_last_lr()}')
print(loss.item())

with open('model-01.pkl', 'wb') as f:
    pickle.dump(model, f)
print('model saved')
# Out:
# 0
# step: 0, train loss: 1.233, val loss: 1.245
# Current learning rate: [9.999999013138289e-05]
# 1
# Current learning rate: [9.999996052553544e-05]
# 2
# Current learning rate: [9.999991118246934e-05]
# 3
# Current learning rate: [9.999984210220407e-05]
# 4
# Current learning rate: [9.999975328476691e-05]
# 5
# Current learning rate: [9.99996447301929e-05]
# 6
# Current learning rate: [9.999951643852494e-05]
# 7
# Current learning rate: [9.999936840981363e-05]
# 8
# Current learning rate: [9.999920064411743e-05]
# 9
# Current learning rate: [9.999901314150258e-05]
# 10
# Current learning rate: [9.999880590204308e-05]
# 11
# Current learning rate: [9.999857892582079e-05]
# 12
# Current learning rate: [9.999833221292526e-05]
# 13
# Current learning rate: [9.999806576345393e-05]
# 14
# Current learning rate: [9.999777957751194e-05]
# 15
# Current learning rate: [9.999747365521233e-05]
# 16
# Current learning rate: [9.999714799667585e-05]
# 17
# Current learning rate: [9.999680260203107e-05]
# 18
# Current learning rate: [9.999643747141434e-05]
# 19
# Current learning rate: [9.99960526049698e-05]
# 20
# Current learning rate: [9.99956480028494e-05]
# 21
# Current learning rate: [9.999522366521285e-05]
# 22
# Current learning rate: [9.99947795922277e-05]
# 23
# Current learning rate: [9.999431578406925e-05]
# 24
# Current learning rate: [9.999383224092063e-05]
# 25
# Current learning rate: [9.999332896297268e-05]
# 26
# Current learning rate: [9.999280595042414e-05]
# 27
# Current learning rate: [9.999226320348146e-05]
# 28
# Current learning rate: [9.99917007223589e-05]
# 29
# Current learning rate: [9.999111850727855e-05]
# 30
# Current learning rate: [9.999051655847023e-05]
# 31
# Current learning rate: [9.99898948761716e-05]
# 32
# Current learning rate: [9.998925346062806e-05]
# 33
# Current learning rate: [9.998859231209288e-05]
# 34
# Current learning rate: [9.998791143082703e-05]
# 35
# Current learning rate: [9.998721081709931e-05]
# 36
# Current learning rate: [9.998649047118634e-05]
# 37
# Current learning rate: [9.998575039337248e-05]
# 38
# Current learning rate: [9.99849905839499e-05]
# 39
# Current learning rate: [9.998421104321858e-05]
# 40
# Current learning rate: [9.998341177148626e-05]
# 41
# Current learning rate: [9.998259276906847e-05]
# 42
# Current learning rate: [9.998175403628856e-05]
# 43
# Current learning rate: [9.998089557347763e-05]
# 44
# Current learning rate: [9.998001738097458e-05]
# 45
# Current learning rate: [9.997911945912613e-05]
# 46
# Current learning rate: [9.997820180828674e-05]
# 47
# Current learning rate: [9.997726442881872e-05]
# 48
# Current learning rate: [9.997630732109211e-05]
# 49
# Current learning rate: [9.997533048548475e-05]
# 50
# Current learning rate: [9.99743339223823e-05]
# 51
# Current learning rate: [9.997331763217818e-05]
# 52
# Current learning rate: [9.99722816152736e-05]
# 53
# Current learning rate: [9.997122587207756e-05]
# 54
# Current learning rate: [9.997015040300687e-05]
# 55
# Current learning rate: [9.99690552084861e-05]
# 56
# Current learning rate: [9.996794028894759e-05]
# 57
# Current learning rate: [9.996680564483154e-05]
# 58
# Current learning rate: [9.996565127658585e-05]
# 59
# Current learning rate: [9.996447718466626e-05]
# 60
# Current learning rate: [9.99632833695363e-05]
# 61
# Current learning rate: [9.996206983166723e-05]
# 62
# Current learning rate: [9.996083657153817e-05]
# 63
# Current learning rate: [9.995958358963596e-05]
# 64
# Current learning rate: [9.995831088645529e-05]
# 65
# Current learning rate: [9.99570184624986e-05]
# 66
# Current learning rate: [9.99557063182761e-05]
# 67
# Current learning rate: [9.995437445430582e-05]
# 68
# Current learning rate: [9.995302287111354e-05]
# 69
# Current learning rate: [9.995165156923286e-05]
# 70
# Current learning rate: [9.995026054920513e-05]
# 71
# Current learning rate: [9.994884981157952e-05]
# 72
# Current learning rate: [9.994741935691296e-05]
# 73
# Current learning rate: [9.994596918577019e-05]
# 74
# Current learning rate: [9.99444992987237e-05]
# 75
# Current learning rate: [9.994300969635375e-05]
# 76
# Current learning rate: [9.994150037924846e-05]
# 77
# Current learning rate: [9.993997134800365e-05]
# 78
# Current learning rate: [9.993842260322298e-05]
# 79
# Current learning rate: [9.993685414551785e-05]
# 80
# Current learning rate: [9.993526597550747e-05]
# 81
# Current learning rate: [9.993365809381883e-05]
# 82
# Current learning rate: [9.99320305010867e-05]
# 83
# Current learning rate: [9.993038319795361e-05]
# 84
# Current learning rate: [9.992871618506989e-05]
# 85
# Current learning rate: [9.992702946309367e-05]
# 86
# Current learning rate: [9.992532303269084e-05]
# 87
# Current learning rate: [9.992359689453505e-05]
# 88
# Current learning rate: [9.992185104930776e-05]
# 89
# Current learning rate: [9.992008549769821e-05]
# 90
# Current learning rate: [9.991830024040341e-05]
# 91
# Current learning rate: [9.991649527812814e-05]
# 92
# Current learning rate: [9.991467061158501e-05]
# 93
# Current learning rate: [9.991282624149432e-05]
# 94
# Current learning rate: [9.991096216858421e-05]
# 95
# Current learning rate: [9.990907839359059e-05]
# 96
# Current learning rate: [9.990717491725716e-05]
# 97
# Current learning rate: [9.990525174033536e-05]
# 98
# Current learning rate: [9.990330886358446e-05]
# 99
# Current learning rate: [9.990134628777144e-05]
# 100
# Current learning rate: [9.989936401367112e-05]
# 101
# Current learning rate: [9.989736204206605e-05]
# 102
# Current learning rate: [9.989534037374661e-05]
# 103
# Current learning rate: [9.989329900951088e-05]
# 104
# Current learning rate: [9.98912379501648e-05]
# 105
# Current learning rate: [9.9889157196522e-05]
# 106
# Current learning rate: [9.988705674940396e-05]
# 107
# Current learning rate: [9.98849366096399e-05]
# 108
# Current learning rate: [9.988279677806681e-05]
# 109
# Current learning rate: [9.988063725552946e-05]
# 110
# Current learning rate: [9.987845804288041e-05]
# 111
# Current learning rate: [9.987625914097996e-05]
# 112
# Current learning rate: [9.98740405506962e-05]
# 113
# Current learning rate: [9.9871802272905e-05]
# 114
# Current learning rate: [9.986954430849003e-05]
# 115
# Current learning rate: [9.986726665834265e-05]
# 116
# Current learning rate: [9.986496932336206e-05]
# 117
# Current learning rate: [9.98626523044552e-05]
# 118
# Current learning rate: [9.986031560253683e-05]
# 119
# Current learning rate: [9.98579592185294e-05]
# 120
# Current learning rate: [9.985558315336318e-05]
# 121
# Current learning rate: [9.985318740797623e-05]
# 122
# Current learning rate: [9.985077198331432e-05]
# 123
# Current learning rate: [9.984833688033106e-05]
# 124
# Current learning rate: [9.984588209998774e-05]
# 125
# Current learning rate: [9.984340764325349e-05]
# 126
# Current learning rate: [9.984091351110521e-05]
# 127
# Current learning rate: [9.983839970452752e-05]
# 128
# Current learning rate: [9.983586622451284e-05]
# 129
# Current learning rate: [9.983331307206132e-05]
# 130
# Current learning rate: [9.983074024818095e-05]
# 131
# Current learning rate: [9.982814775388742e-05]
# 132
# Current learning rate: [9.982553559020419e-05]
# 133
# Current learning rate: [9.982290375816251e-05]
# 134
# Current learning rate: [9.98202522588014e-05]
# 135
# Current learning rate: [9.981758109316761e-05]
# 136
# Current learning rate: [9.98148902623157e-05]
# 137
# Current learning rate: [9.981217976730795e-05]
# 138
# Current learning rate: [9.980944960921441e-05]
# 139
# Current learning rate: [9.980669978911291e-05]
# 140
# Current learning rate: [9.980393030808905e-05]
# 141
# Current learning rate: [9.980114116723616e-05]
# 142
# Current learning rate: [9.979833236765537e-05]
# 143
# Current learning rate: [9.979550391045553e-05]
# 144
# Current learning rate: [9.979265579675326e-05]
# 145
# Current learning rate: [9.978978802767297e-05]
# 146
# Current learning rate: [9.978690060434683e-05]
# 147
# Current learning rate: [9.97839935279147e-05]
# 148
# Current learning rate: [9.978106679952427e-05]
# 149
# Current learning rate: [9.9778120420331e-05]
# 150
# Current learning rate: [9.977515439149801e-05]
# 151
# Current learning rate: [9.977216871419628e-05]
# 152
# Current learning rate: [9.97691633896045e-05]
# 153
# Current learning rate: [9.976613841890914e-05]
# 154
# Current learning rate: [9.97630938033044e-05]
# 155
# Current learning rate: [9.976002954399222e-05]
# 156
# Current learning rate: [9.975694564218236e-05]
# 157
# Current learning rate: [9.975384209909227e-05]
# 158
# Current learning rate: [9.97507189159472e-05]
# 159
# Current learning rate: [9.974757609398012e-05]
# 160
# Current learning rate: [9.974441363443175e-05]
# 161
# Current learning rate: [9.974123153855061e-05]
# 162
# Current learning rate: [9.973802980759293e-05]
# 163
# Current learning rate: [9.97348084428227e-05]
# 164
# Current learning rate: [9.973156744551166e-05]
# 165
# Current learning rate: [9.972830681693932e-05]
# 166
# Current learning rate: [9.972502655839291e-05]
# 167
# Current learning rate: [9.972172667116743e-05]
# 168
# Current learning rate: [9.971840715656561e-05]
# 169
# Current learning rate: [9.971506801589797e-05]
# 170
# Current learning rate: [9.971170925048272e-05]
# 171
# Current learning rate: [9.970833086164586e-05]
# 172
# Current learning rate: [9.970493285072114e-05]
# 173
# Current learning rate: [9.970151521905001e-05]
# 174
# Current learning rate: [9.969807796798171e-05]
# 175
# Current learning rate: [9.969462109887323e-05]
# 176
# Current learning rate: [9.969114461308926e-05]
# 177
# Current learning rate: [9.968764851200227e-05]
# 178
# Current learning rate: [9.96841327969925e-05]
# 179
# Current learning rate: [9.968059746944783e-05]
# 180
# Current learning rate: [9.967704253076399e-05]
# 181
# Current learning rate: [9.967346798234442e-05]
# 182
# Current learning rate: [9.96698738256003e-05]
# 183
# Current learning rate: [9.966626006195053e-05]
# 184
# Current learning rate: [9.966262669282176e-05]
# 185
# Current learning rate: [9.965897371964841e-05]
# 186
# Current learning rate: [9.965530114387258e-05]
# 187
# Current learning rate: [9.96516089669442e-05]
# 188
# Current learning rate: [9.964789719032082e-05]
# 189
# Current learning rate: [9.964416581546784e-05]
# 190
# Current learning rate: [9.964041484385831e-05]
# 191
# Current learning rate: [9.96366442769731e-05]
# 192
# Current learning rate: [9.963285411630073e-05]
# 193
# Current learning rate: [9.96290443633375e-05]
# 194
# Current learning rate: [9.962521501958746e-05]
# 195
# Current learning rate: [9.962136608656236e-05]
# 196
# Current learning rate: [9.96174975657817e-05]
# 197
# Current learning rate: [9.961360945877271e-05]
# 198
# Current learning rate: [9.960970176707036e-05]
# 199
# Current learning rate: [9.960577449221733e-05]
# 200
# Current learning rate: [9.960182763576405e-05]
# 201
# Current learning rate: [9.959786119926869e-05]
# 202
# Current learning rate: [9.959387518429714e-05]
# 203
# Current learning rate: [9.9589869592423e-05]
# 204
# Current learning rate: [9.958584442522761e-05]
# 205
# Current learning rate: [9.958179968430004e-05]
# 206
# Current learning rate: [9.957773537123712e-05]
# 207
# Current learning rate: [9.957365148764332e-05]
# 208
# Current learning rate: [9.956954803513096e-05]
# 209
# Current learning rate: [9.956542501531999e-05]
# 210
# Current learning rate: [9.956128242983809e-05]
# 211
# Current learning rate: [9.955712028032073e-05]
# 212
# Current learning rate: [9.955293856841102e-05]
# 213
# Current learning rate: [9.954873729575986e-05]
# 214
# Current learning rate: [9.954451646402582e-05]
# 215
# Current learning rate: [9.954027607487525e-05]
# 216
# Current learning rate: [9.953601612998217e-05]
# 217
# Current learning rate: [9.953173663102836e-05]
# 218
# Current learning rate: [9.952743757970325e-05]
# 219
# Current learning rate: [9.952311897770407e-05]
# 220
# Current learning rate: [9.951878082673575e-05]
# 221
# Current learning rate: [9.95144231285109e-05]
# 222
# Current learning rate: [9.951004588474989e-05]
# 223
# Current learning rate: [9.950564909718077e-05]
# 224
# Current learning rate: [9.95012327675393e-05]
# 225
# Current learning rate: [9.949679689756902e-05]
# 226
# Current learning rate: [9.949234148902112e-05]
# 227
# Current learning rate: [9.948786654365453e-05]
# 228
# Current learning rate: [9.948337206323589e-05]
# 229
# Current learning rate: [9.947885804953953e-05]
# 230
# Current learning rate: [9.947432450434755e-05]
# 231
# Current learning rate: [9.946977142944969e-05]
# 232
# Current learning rate: [9.946519882664343e-05]
# 233
# Current learning rate: [9.946060669773399e-05]
# 234
# Current learning rate: [9.945599504453423e-05]
# 235
# Current learning rate: [9.945136386886479e-05]
# 236
# Current learning rate: [9.944671317255398e-05]
# 237
# Current learning rate: [9.94420429574378e-05]
# 238
# Current learning rate: [9.943735322536e-05]
# 239
# Current learning rate: [9.943264397817201e-05]
# 240
# Current learning rate: [9.942791521773296e-05]
# 241
# Current learning rate: [9.942316694590969e-05]
# 242
# Current learning rate: [9.941839916457673e-05]
# 243
# Current learning rate: [9.941361187561634e-05]
# 244
# Current learning rate: [9.940880508091848e-05]
# 245
# Current learning rate: [9.940397878238076e-05]
# 246
# Current learning rate: [9.939913298190855e-05]
# 247
# Current learning rate: [9.939426768141491e-05]
# 248
# Current learning rate: [9.938938288282055e-05]
# 249
# Current learning rate: [9.938447858805392e-05]
# 250
# Current learning rate: [9.937955479905117e-05]
# 251
# Current learning rate: [9.937461151775611e-05]
# 252
# Current learning rate: [9.93696487461203e-05]
# 253
# Current learning rate: [9.936466648610297e-05]
# 254
# Current learning rate: [9.935966473967099e-05]
# 255
# Current learning rate: [9.935464350879901e-05]
# 256
# Current learning rate: [9.934960279546932e-05]
# 257
# Current learning rate: [9.93445426016719e-05]
# 258
# Current learning rate: [9.933946292940446e-05]
# 259
# Current learning rate: [9.933436378067236e-05]
# 260
# Current learning rate: [9.932924515748867e-05]
# 261
# Current learning rate: [9.932410706187414e-05]
# 262
# Current learning rate: [9.931894949585721e-05]
# 263
# Current learning rate: [9.931377246147399e-05]
# 264
# Current learning rate: [9.930857596076831e-05]
# 265
# Current learning rate: [9.930335999579165e-05]
# 266
# Current learning rate: [9.92981245686032e-05]
# 267
# Current learning rate: [9.929286968126983e-05]
# 268
# Current learning rate: [9.928759533586607e-05]
# 269
# Current learning rate: [9.928230153447416e-05]
# 270
# Current learning rate: [9.927698827918401e-05]
# 271
# Current learning rate: [9.92716555720932e-05]
# 272
# Current learning rate: [9.9266303415307e-05]
# 273
# Current learning rate: [9.926093181093838e-05]
# 274
# Current learning rate: [9.925554076110793e-05]
# 275
# Current learning rate: [9.925013026794396e-05]
# 276
# Current learning rate: [9.924470033358247e-05]
# 277
# Current learning rate: [9.923925096016708e-05]
# 278
# Current learning rate: [9.923378214984912e-05]
# 279
# Current learning rate: [9.922829390478763e-05]
# 280
# Current learning rate: [9.922278622714924e-05]
# 281
# Current learning rate: [9.92172591191083e-05]
# 282
# Current learning rate: [9.921171258284684e-05]
# 283
# Current learning rate: [9.920614662055452e-05]
# 284
# Current learning rate: [9.920056123442874e-05]
# 285
# Current learning rate: [9.919495642667448e-05]
# 286
# Current learning rate: [9.918933219950442e-05]
# 287
# Current learning rate: [9.918368855513897e-05]
# 288
# Current learning rate: [9.91780254958061e-05]
# 289
# Current learning rate: [9.917234302374151e-05]
# 290
# Current learning rate: [9.916664114118857e-05]
# 291
# Current learning rate: [9.916091985039826e-05]
# 292
# Current learning rate: [9.915517915362928e-05]
# 293
# Current learning rate: [9.914941905314797e-05]
# 294
# Current learning rate: [9.91436395512283e-05]
# 295
# Current learning rate: [9.913784065015194e-05]
# 296
# Current learning rate: [9.913202235220822e-05]
# 297
# Current learning rate: [9.91261846596941e-05]
# 298
# Current learning rate: [9.912032757491419e-05]
# 299
# Current learning rate: [9.91144511001808e-05]
# 300
# Current learning rate: [9.910855523781384e-05]
# 301
# Current learning rate: [9.910263999014095e-05]
# 302
# Current learning rate: [9.909670535949733e-05]
# 303
# Current learning rate: [9.90907513482259e-05]
# 304
# Current learning rate: [9.908477795867722e-05]
# 305
# Current learning rate: [9.907878519320946e-05]
# 306
# Current learning rate: [9.90727730541885e-05]
# 307
# Current learning rate: [9.906674154398781e-05]
# 308
# Current learning rate: [9.906069066498854e-05]
# 309
# Current learning rate: [9.905462041957948e-05]
# 310
# Current learning rate: [9.90485308101571e-05]
# 311
# Current learning rate: [9.904242183912546e-05]
# 312
# Current learning rate: [9.903629350889626e-05]
# 313
# Current learning rate: [9.903014582188888e-05]
# 314
# Current learning rate: [9.902397878053036e-05]
# 315
# Current learning rate: [9.901779238725533e-05]
# 316
# Current learning rate: [9.901158664450606e-05]
# 317
# Current learning rate: [9.900536155473251e-05]
# 318
# Current learning rate: [9.899911712039223e-05]
# 319
# Current learning rate: [9.899285334395042e-05]
# 320
# Current learning rate: [9.898657022787993e-05]
# 321
# Current learning rate: [9.898026777466125e-05]
# 322
# Current learning rate: [9.897394598678245e-05]
# 323
# Current learning rate: [9.896760486673931e-05]
# 324
# Current learning rate: [9.896124441703518e-05]
# 325
# Current learning rate: [9.895486464018107e-05]
# 326
# Current learning rate: [9.894846553869562e-05]
# 327
# Current learning rate: [9.89420471151051e-05]
# 328
# Current learning rate: [9.893560937194337e-05]
# 329
# Current learning rate: [9.892915231175198e-05]
# 330
# Current learning rate: [9.892267593708008e-05]
# 331
# Current learning rate: [9.89161802504844e-05]
# 332
# Current learning rate: [9.890966525452937e-05]
# 333
# Current learning rate: [9.890313095178701e-05]
# 334
# Current learning rate: [9.889657734483695e-05]
# 335
# Current learning rate: [9.889000443626643e-05]
# 336
# Current learning rate: [9.888341222867036e-05]
# 337
# Current learning rate: [9.887680072465122e-05]
# 338
# Current learning rate: [9.887016992681914e-05]
# 339
# Current learning rate: [9.886351983779184e-05]
# 340
# Current learning rate: [9.885685046019468e-05]
# 341
# Current learning rate: [9.885016179666063e-05]
# 342
# Current learning rate: [9.884345384983025e-05]
# 343
# Current learning rate: [9.883672662235174e-05]
# 344
# Current learning rate: [9.882998011688091e-05]
# 345
# Current learning rate: [9.882321433608118e-05]
# 346
# Current learning rate: [9.881642928262354e-05]
# 347
# Current learning rate: [9.880962495918666e-05]
# 348
# Current learning rate: [9.880280136845676e-05]
# 349
# Current learning rate: [9.879595851312768e-05]
# 350
# Current learning rate: [9.878909639590088e-05]
# 351
# Current learning rate: [9.878221501948543e-05]
# 352
# Current learning rate: [9.877531438659795e-05]
# 353
# Current learning rate: [9.876839449996273e-05]
# 354
# Current learning rate: [9.876145536231163e-05]
# 355
# Current learning rate: [9.87544969763841e-05]
# 356
# Current learning rate: [9.87475193449272e-05]
# 357
# Current learning rate: [9.874052247069562e-05]
# 358
# Current learning rate: [9.873350635645156e-05]
# 359
# Current learning rate: [9.872647100496493e-05]
# 360
# Current learning rate: [9.871941641901314e-05]
# 361
# Current learning rate: [9.871234260138122e-05]
# 362
# Current learning rate: [9.870524955486183e-05]
# 363
# Current learning rate: [9.869813728225517e-05]
# 364
# Current learning rate: [9.869100578636906e-05]
# 365
# Current learning rate: [9.86838550700189e-05]
# 366
# Current learning rate: [9.86766851360277e-05]
# 367
# Current learning rate: [9.866949598722601e-05]
# 368
# Current learning rate: [9.8662287626452e-05]
# 369
# Current learning rate: [9.865506005655143e-05]
# 370
# Current learning rate: [9.86478132803776e-05]
# 371
# Current learning rate: [9.864054730079144e-05]
# 372
# Current learning rate: [9.863326212066146e-05]
# 373
# Current learning rate: [9.862595774286371e-05]
# 374
# Current learning rate: [9.861863417028185e-05]
# 375
# Current learning rate: [9.861129140580711e-05]
# 376
# Current learning rate: [9.86039294523383e-05]
# 377
# Current learning rate: [9.859654831278179e-05]
# 378
# Current learning rate: [9.858914799005157e-05]
# 379
# Current learning rate: [9.858172848706913e-05]
# 380
# Current learning rate: [9.85742898067636e-05]
# 381
# Current learning rate: [9.856683195207162e-05]
# 382
# Current learning rate: [9.855935492593749e-05]
# 383
# Current learning rate: [9.855185873131296e-05]
# 384
# Current learning rate: [9.854434337115746e-05]
# 385
# Current learning rate: [9.85368088484379e-05]
# 386
# Current learning rate: [9.85292551661288e-05]
# 387
# Current learning rate: [9.852168232721226e-05]
# 388
# Current learning rate: [9.851409033467786e-05]
# 389
# Current learning rate: [9.850647919152284e-05]
# 390
# Current learning rate: [9.849884890075197e-05]
# 391
# Current learning rate: [9.849119946537753e-05]
# 392
# Current learning rate: [9.848353088841942e-05]
# 393
# Current learning rate: [9.847584317290507e-05]
# 394
# Current learning rate: [9.846813632186945e-05]
# 395
# Current learning rate: [9.846041033835512e-05]
# 396
# Current learning rate: [9.845266522541219e-05]
# 397
# Current learning rate: [9.844490098609829e-05]
# 398
# Current learning rate: [9.843711762347862e-05]
# 399
# Current learning rate: [9.842931514062592e-05]
# 400
# Current learning rate: [9.842149354062051e-05]
# 401
# Current learning rate: [9.841365282655019e-05]
# 402
# Current learning rate: [9.840579300151041e-05]
# 403
# Current learning rate: [9.839791406860406e-05]
# 404
# Current learning rate: [9.839001603094163e-05]
# 405
# Current learning rate: [9.838209889164115e-05]
# 406
# Current learning rate: [9.837416265382817e-05]
# 407
# Current learning rate: [9.83662073206358e-05]
# 408
# Current learning rate: [9.835823289520466e-05]
# 409
# Current learning rate: [9.835023938068295e-05]
# 410
# Current learning rate: [9.834222678022635e-05]
# 411
# Current learning rate: [9.833419509699817e-05]
# 412
# Current learning rate: [9.832614433416914e-05]
# 413
# Current learning rate: [9.831807449491758e-05]
# 414
# Current learning rate: [9.830998558242933e-05]
# 415
# Current learning rate: [9.830187759989779e-05]
# 416
# Current learning rate: [9.829375055052383e-05]
# 417
# Current learning rate: [9.828560443751592e-05]
# 418
# Current learning rate: [9.827743926409e-05]
# 419
# Current learning rate: [9.826925503346953e-05]
# 420
# Current learning rate: [9.826105174888555e-05]
# 421
# Current learning rate: [9.825282941357655e-05]
# 422
# Current learning rate: [9.824458803078859e-05]
# 423
# Current learning rate: [9.823632760377527e-05]
# 424
# Current learning rate: [9.822804813579762e-05]
# 425
# Current learning rate: [9.821974963012428e-05]
# 426
# Current learning rate: [9.821143209003137e-05]
# 427
# Current learning rate: [9.820309551880251e-05]
# 428
# Current learning rate: [9.819473991972886e-05]
# 429
# Current learning rate: [9.818636529610905e-05]
# 430
# Current learning rate: [9.817797165124927e-05]
# 431
# Current learning rate: [9.816955898846318e-05]
# 432
# Current learning rate: [9.816112731107201e-05]
# 433
# Current learning rate: [9.81526766224044e-05]
# 434
# Current learning rate: [9.81442069257966e-05]
# 435
# Current learning rate: [9.813571822459226e-05]
# 436
# Current learning rate: [9.812721052214261e-05]
# 437
# Current learning rate: [9.811868382180636e-05]
# 438
# Current learning rate: [9.811013812694972e-05]
# 439
# Current learning rate: [9.810157344094637e-05]
# 440
# Current learning rate: [9.809298976717753e-05]
# 441
# Current learning rate: [9.80843871090319e-05]
# 442
# Current learning rate: [9.807576546990568e-05]
# 443
# Current learning rate: [9.806712485320255e-05]
# 444
# Current learning rate: [9.805846526233365e-05]
# 445
# Current learning rate: [9.804978670071771e-05]
# 446
# Current learning rate: [9.804108917178086e-05]
# 447
# Current learning rate: [9.803237267895676e-05]
# 448
# Current learning rate: [9.802363722568652e-05]
# 449
# Current learning rate: [9.801488281541878e-05]
# 450
# Current learning rate: [9.800610945160962e-05]
# 451
# Current learning rate: [9.799731713772266e-05]
# 452
# Current learning rate: [9.798850587722893e-05]
# 453
# Current learning rate: [9.7979675673607e-05]
# 454
# Current learning rate: [9.797082653034288e-05]
# 455
# Current learning rate: [9.796195845093008e-05]
# 456
# Current learning rate: [9.795307143886957e-05]
# 457
# Current learning rate: [9.794416549766982e-05]
# 458
# Current learning rate: [9.793524063084673e-05]
# 459
# Current learning rate: [9.79262968419237e-05]
# 460
# Current learning rate: [9.791733413443163e-05]
# 461
# Current learning rate: [9.790835251190881e-05]
# 462
# Current learning rate: [9.789935197790108e-05]
# 463
# Current learning rate: [9.789033253596167e-05]
# 464
# Current learning rate: [9.788129418965133e-05]
# 465
# Current learning rate: [9.787223694253826e-05]
# 466
# Current learning rate: [9.786316079819813e-05]
# 467
# Current learning rate: [9.785406576021404e-05]
# 468
# Current learning rate: [9.784495183217655e-05]
# 469
# Current learning rate: [9.783581901768374e-05]
# 470
# Current learning rate: [9.782666732034106e-05]
# 471
# Current learning rate: [9.781749674376148e-05]
# 472
# Current learning rate: [9.780830729156539e-05]
# 473
# Current learning rate: [9.779909896738063e-05]
# 474
# Current learning rate: [9.778987177484251e-05]
# 475
# Current learning rate: [9.77806257175938e-05]
# 476
# Current learning rate: [9.777136079928466e-05]
# 477
# Current learning rate: [9.776207702357274e-05]
# 478
# Current learning rate: [9.775277439412316e-05]
# 479
# Current learning rate: [9.774345291460842e-05]
# 480
# Current learning rate: [9.77341125887085e-05]
# 481
# Current learning rate: [9.77247534201108e-05]
# 482
# Current learning rate: [9.771537541251021e-05]
# 483
# Current learning rate: [9.770597856960897e-05]
# 484
# Current learning rate: [9.769656289511685e-05]
# 485
# Current learning rate: [9.768712839275097e-05]
# 486
# Current learning rate: [9.767767506623595e-05]
# 487
# Current learning rate: [9.76682029193038e-05]
# 488
# Current learning rate: [9.765871195569398e-05]
# 489
# Current learning rate: [9.764920217915337e-05]
# 490
# Current learning rate: [9.763967359343627e-05]
# 491
# Current learning rate: [9.763012620230442e-05]
# 492
# Current learning rate: [9.762056000952698e-05]
# 493
# Current learning rate: [9.761097501888056e-05]
# 494
# Current learning rate: [9.760137123414911e-05]
# 495
# Current learning rate: [9.759174865912408e-05]
# 496
# Current learning rate: [9.758210729760432e-05]
# 497
# Current learning rate: [9.757244715339606e-05]
# 498
# Current learning rate: [9.7562768230313e-05]
# 499
# Current learning rate: [9.755307053217622e-05]
# 500

# %%
prompt = 'Hello! Can you see me?'
context = torch.tensor(encode(prompt), dtype=torch.long, device=device)
generated_chars = decode(m.generate(context.unsqueeze(0), max_new_tokens=100, temperature = temperature)[0].tolist())
print(generated_chars)
# Out:
# Hello! Can you see me? She got before working future/shown by the selection of the same politically place was an pretty se
